# %%
#import require python classes and packages
import cv2
import numpy as np
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from keras.utils import to_categorical
import pickle
from sklearn.metrics import confusion_matrix #class to calculate accuracy and other metrics
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
import seaborn as sns
import matplotlib.pyplot as plt
from keras.callbacks import ModelCheckpoint
import keras
from keras import Model, layers
import pandas as pd
from keras.optimizers import SGD #import SGD class
from keras.optimizers import Adam #import Adam class optimizer
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense, InputLayer, BatchNormalization, Dropout
import warnings
warnings.filterwarnings('ignore')

# %%
#define global variables
X = []
Y = []
path = r"C:\Users\Adil shaik\PycharmProjects\PythonProject\.venv\EyeNetDeepNeuralNetwork\SelectedImages"
labels = []

# %%
#define function to load class labels
for root, dirs, directory in os.walk(path):
    for j in range(len(directory)):
        name = os.path.basename(root)
        if name not in labels:
            labels.append(name.strip())
def getLabel(name):
    index = -1
    for i in range(len(labels)):
        if labels[i] == name:
            index = i
            break
    return index
print("Retinal Diseases Class Labels found in dataset : "+str(labels))
# Out:
# Retinal Diseases Class Labels found in dataset : ['DR', 'MH', 'Normal', 'ODC']

# %%
#loop and read all images from dataset
if os.path.exists(r'C:\Users\Adil shaik\PycharmProjects\PythonProject\.venv\EyeNetDeepNeuralNetwork\model/X.txt.npy'):#if images already processed then load all images
    X = np.load(r'C:\Users\Adil shaik\PycharmProjects\PythonProject\.venv\EyeNetDeepNeuralNetwork\model/X.txt.npy')
    Y = np.load(r'C:\Users\Adil shaik\PycharmProjects\PythonProject\.venv\EyeNetDeepNeuralNetwork\model/Y.txt.npy')
else:#if not processed then read and process each image
    X = []
    Y = []
    for root, dirs, directory in os.walk(path):
        for j in range(len(directory)):
            name = os.path.basename(root)
            if 'Thumbs.db' not in directory[j]:
                img = cv2.imread(root+"/"+directory[j])#read image
                img = cv2.resize(img, (32, 32))#resize image
                X.append(img)#addin images features to training array
                label = getLabel(name)
                Y.append(label)
    X = np.asarray(X)
    Y = np.asarray(Y)
    np.save(r'C:\Users\Adil shaik\PycharmProjects\PythonProject\.venv\EyeNetDeepNeuralNetwork\model/X.txt',X)
    np.save(r'C:\Users\Adil shaik\PycharmProjects\PythonProject\.venv\EyeNetDeepNeuralNetwork\model/Y.txt',Y)            
print("Dataset Loading Completed")
print("Total images found in dataset Before Augmentation : "+str(X.shape[0]))
# Out:
# Dataset Loading Completed
# Total images found in dataset Before Augmentation : 1376

# %%
#visualizing class labels count found in dataset
names, count = np.unique(Y, return_counts = True)
height = count
bars = labels
y_pos = np.arange(len(bars))
plt.figure(figsize = (5, 3)) 
plt.bar(y_pos, height)
plt.xticks(y_pos, bars)
plt.xlabel("Dataset Class Label Graph Before Augmentation")
plt.ylabel("Count")
plt.xticks(rotation=90)
plt.show()

# %%
#preprocess images like shuffling and normalization
X = X.astype('float32')
X = X/255 #normalized pixel values between 0 and 1
indices = np.arange(X.shape[0])
np.random.shuffle(indices) #shuffle all images
X = X[indices]
Y = Y[indices]
Y = to_categorical(Y)
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2) #split dataset into train and test
#now apply augmentation on splitted train images
if os.path.exists(r'C:\Users\Adil shaik\PycharmProjects\PythonProject\.venv\EyeNetDeepNeuralNetwork\model/aug_X.txt.npy'):
    X = np.load(r'C:\Users\Adil shaik\PycharmProjects\PythonProject\.venv\EyeNetDeepNeuralNetwork\model/aug_X.txt.npy')
    Y = np.load(r'C:\Users\Adil shaik\PycharmProjects\PythonProject\.venv\EyeNetDeepNeuralNetwork\model/aug_Y.txt.npy')
else:
    aug = ImageDataGenerator(rotation_range=15, shear_range=0.8, horizontal_flip=True)#apply augmentation to increase images
    data = aug.flow(X_train, y_train, 1)
    X = []
    Y = []  
    for x, y in data:
        x = x[0]
        y = y[0]
        X.append(x)
        Y.append(y)
        if len(Y) > 30000:
            break    
    X = np.asarray(X)
    Y = np.asarray(Y)
    np.save(r'C:\Users\Adil shaik\PycharmProjects\PythonProject\.venv\EyeNetDeepNeuralNetwork\model/aug_X.txt',X)
    np.save(r'C:\Users\Adil shaik\PycharmProjects\PythonProject\.venv\EyeNetDeepNeuralNetwork\model/aug_Y.txt',Y)
print("Image Augmentation Completed")
print("Total images found in dataset After Augmentation : "+str(X.shape[0]))
# Out:
# Image Augmentation Completed
# Total images found in dataset After Augmentation : 30001

# %%
#plotting graph of augmented images class labels
names, count = np.unique(np.argmax(Y, axis=1), return_counts=True)
height = count
bars = labels
y_pos = np.arange(len(bars))
plt.figure(figsize = (5, 3)) 
plt.bar(y_pos, height)
plt.xticks(y_pos, bars)
plt.xlabel("Dataset Class Label Graph After Augmentation")
plt.ylabel("Count")
plt.xticks(rotation=90)
plt.show()

# %%
#split dataset into train and test
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2)
print("Training Images Size   : "+str(X_train.shape[0]))
print("Validation Images Size : "+str(X_val.shape[0]))
print("Testing Images Size    : "+str(X_test.shape[0]))
# Out:
# Training Images Size   : 19200
# Validation Images Size : 4800
# Testing Images Size    : 6001

# %%
#define global variables to save accuracy and other metrics
accuracy = []
precision = []
recall = []
fscore = []

# %%
def calculateMetrics(algorithm, predict, y_test):
    a = accuracy_score(y_test,predict)*100
    p = precision_score(y_test, predict,average='macro') * 100
    r = recall_score(y_test, predict,average='macro') * 100
    f = f1_score(y_test, predict,average='macro') * 100
    accuracy.append(a)
    precision.append(p)
    recall.append(r)
    fscore.append(f)
    print(algorithm+" Accuracy  :  "+str(a))
    print(algorithm+" Precision : "+str(p))
    print(algorithm+" Recall    : "+str(r))
    print(algorithm+" FScore    : "+str(f))    
    conf_matrix = confusion_matrix(y_test, predict) 
    plt.figure(figsize =(6, 3)) 
    ax = sns.heatmap(conf_matrix, xticklabels = labels, yticklabels = labels, annot = True, cmap="viridis" ,fmt ="g");
    ax.set_ylim([0,len(labels)])
    plt.title(algorithm+" Confusion matrix") 
    plt.xticks(rotation=90)
    plt.ylabel('True class') 
    plt.xlabel('Predicted class') 
    plt.show()

# %%
#train eyenet model using SGD optimizer fixed learning rate
eyenet_model = keras.models.Sequential([
    keras.layers.Conv2D(filters=32, kernel_size=(11,11), strides=(4,4), activation='relu', input_shape=(X_train.shape[1],X_train.shape[2],X_train.shape[3])),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(1,1), strides=(2,2)),
    keras.layers.Conv2D(filters=16, kernel_size=(9,9), strides=(1,1), activation='relu', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(1,1), strides=(2,2)),
    keras.layers.Conv2D(filters=8, kernel_size=(7,7), strides=(1,1), activation='relu', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(1,1), strides=(2,2)),
    keras.layers.Conv2D(filters=8, kernel_size=(6,6), strides=(1,1), activation='relu', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(1,1), strides=(2,2)),
    keras.layers.Conv2D(filters=8, kernel_size=(5,5), strides=(1,1), activation='relu', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(1,1), strides=(2,2)),
    keras.layers.Conv2D(filters=8, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(filters=8, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(filters=8, kernel_size=(3,3), strides=(2,2), activation='relu', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(1,1), strides=(2,2)),
    keras.layers.Flatten(),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(y_train.shape[1], activation='softmax')
])
#compiling, training and loading the model
opt = SGD(learning_rate=0.001)
eyenet_model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])#compiling the model
if os.path.exists(r"C:\Users\Adil shaik\PycharmProjects\PythonProject\.venv\EyeNetDeepNeuralNetwork\model/sgd_weights.keras") == False:
    model_check_point = ModelCheckpoint(filepath=r'C:\Users\Adil shaik\PycharmProjects\PythonProject\.venv\EyeNetDeepNeuralNetwork\model/sgd_weights.keras', verbose = 1, save_best_only = True)
    hist = eyenet_model.fit(X_train, y_train, epochs = 40, validation_data=(X_test, y_test), callbacks=[model_check_point], verbose=1)
    f = open(r'C:\Users\Adil shaik\PycharmProjects\PythonProject\.venv\EyeNetDeepNeuralNetwork\model/sgd_history.pckl', 'wb')
    pickle.dump(hist.history, f)
    f.close()    
else:
    eyenet_model.load_weights(r"C:\Users\Adil shaik\PycharmProjects\PythonProject\.venv\EyeNetDeepNeuralNetwork\model/sgd_weights.keras")
#perfrom prediction on test data
predict = eyenet_model.predict(X_val)
predict = np.argmax(predict, axis=1)
y_val1 = np.argmax(y_val, axis=1)
acc = accuracy_score(y_val1, predict) * 100
print("EyeNet SGD Validation Accuracy  :  "+str(acc))
predict = eyenet_model.predict(X_test)
predict = np.argmax(predict, axis=1)
y_test1 = np.argmax(y_test, axis=1)
calculateMetrics("EyeNet SGD Testing", predict, y_test1)
# Out:
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# EyeNet SGD Validation Accuracy  :  79.70833333333334
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# EyeNet SGD Testing Accuracy  :  78.6535577403766
# EyeNet SGD Testing Precision : 78.22262183672579
# EyeNet SGD Testing Recall    : 76.6629811803451
# EyeNet SGD Testing FScore    : 76.25860497254624

# %%
#training EyeNet with Adam Optimizer
opt = Adam(learning_rate=0.001)#defining Adam
eyenet_model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])#compiling the model
#compiling, training and loading the model
if os.path.exists(r"C:\Users\Adil shaik\PycharmProjects\PythonProject\.venv\EyeNetDeepNeuralNetwork\model/adam_weights.keras") == False:
    model_check_point = ModelCheckpoint(filepath=r'C:\Users\Adil shaik\PycharmProjects\PythonProject\.venv\EyeNetDeepNeuralNetwork\model/adam_weights.keras', verbose = 1, save_best_only = True)
    hist = eyenet_model.fit(X_train, y_train, epochs = 40, validation_data=(X_test, y_test), callbacks=[model_check_point], verbose=1)
    f = open(r'C:\Users\Adil shaik\PycharmProjects\PythonProject\.venv\EyeNetDeepNeuralNetwork\model/adam_history.pckl', 'wb')
    pickle.dump(hist.history, f)
    f.close()    
else:
    eyenet_model.load_weights(r"C:\Users\Adil shaik\PycharmProjects\PythonProject\.venv\EyeNetDeepNeuralNetwork\model/adam_weights.keras")
#perfrom prediction on test data
predict = eyenet_model.predict(X_val)
predict = np.argmax(predict, axis=1)
y_val1 = np.argmax(y_val, axis=1)
acc = accuracy_score(y_val1, predict) * 100
print("EyeNet Adam Validation Accuracy  :  "+str(acc))
predict = eyenet_model.predict(X_test)
predict = np.argmax(predict, axis=1)
y_test1 = np.argmax(y_test, axis=1)
calculateMetrics("EyeNet Adam Testing", predict, y_test1)
# Out:
# Epoch 1/40
# 594/600 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5889 - loss: 1.0542
# Epoch 1: val_loss improved from inf to 1.31597, saving model to C:\Users\cimss\PycharmProjects\Deepnet\venv\EyeNetDeepNeuralNetwork\model/adam_weights.keras
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.5891 - loss: 1.0537 - val_accuracy: 0.5517 - val_loss: 1.3160
# Epoch 2/40
# 599/600 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6336 - loss: 0.9504
# Epoch 2: val_loss improved from 1.31597 to 0.87695, saving model to C:\Users\cimss\PycharmProjects\Deepnet\venv\EyeNetDeepNeuralNetwork\model/adam_weights.keras
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.6336 - loss: 0.9504 - val_accuracy: 0.6539 - val_loss: 0.8770
# Epoch 3/40
# 597/600 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6555 - loss: 0.8968
# Epoch 3: val_loss improved from 0.87695 to 0.81347, saving model to C:\Users\cimss\PycharmProjects\Deepnet\venv\EyeNetDeepNeuralNetwork\model/adam_weights.keras
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.6556 - loss: 0.8966 - val_accuracy: 0.6829 - val_loss: 0.8135
# Epoch 4/40
# 598/600 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6755 - loss: 0.8292
# Epoch 4: val_loss did not improve from 0.81347
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.6755 - loss: 0.8292 - val_accuracy: 0.5707 - val_loss: 1.2493
# Epoch 5/40
# 596/600 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6939 - loss: 0.7879
# Epoch 5: val_loss did not improve from 0.81347
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.6938 - loss: 0.7879 - val_accuracy: 0.5049 - val_loss: 1.7182
# Epoch 6/40
# 597/600 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6983 - loss: 0.7540
# Epoch 6: val_loss did not improve from 0.81347
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.6983 - loss: 0.7540 - val_accuracy: 0.6334 - val_loss: 0.9160
# Epoch 7/40
# 599/600 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7209 - loss: 0.7231
# Epoch 7: val_loss did not improve from 0.81347
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.7209 - loss: 0.7230 - val_accuracy: 0.6659 - val_loss: 0.8490
# Epoch 8/40
# 598/600 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7265 - loss: 0.7066
# Epoch 8: val_loss improved from 0.81347 to 0.75617, saving model to C:\Users\cimss\PycharmProjects\Deepnet\venv\EyeNetDeepNeuralNetwork\model/adam_weights.keras
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.7266 - loss: 0.7065 - val_accuracy: 0.7079 - val_loss: 0.7562
# Epoch 9/40
# 594/600 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7409 - loss: 0.6617
# Epoch 9: val_loss did not improve from 0.75617
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.7409 - loss: 0.6618 - val_accuracy: 0.6834 - val_loss: 0.8076
# Epoch 10/40
# 596/600 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7544 - loss: 0.6375
# Epoch 10: val_loss improved from 0.75617 to 0.67438, saving model to C:\Users\cimss\PycharmProjects\Deepnet\venv\EyeNetDeepNeuralNetwork\model/adam_weights.keras
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.7544 - loss: 0.6375 - val_accuracy: 0.7235 - val_loss: 0.6744
# Epoch 11/40
# 596/600 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7640 - loss: 0.6083
# Epoch 11: val_loss did not improve from 0.67438
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.7639 - loss: 0.6083 - val_accuracy: 0.6171 - val_loss: 0.9915
# Epoch 12/40
# 596/600 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7680 - loss: 0.6095
# Epoch 12: val_loss improved from 0.67438 to 0.58524, saving model to C:\Users\cimss\PycharmProjects\Deepnet\venv\EyeNetDeepNeuralNetwork\model/adam_weights.keras
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.7680 - loss: 0.6094 - val_accuracy: 0.7602 - val_loss: 0.5852
# Epoch 13/40
# 594/600 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7765 - loss: 0.5755
# Epoch 13: val_loss did not improve from 0.58524
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.7766 - loss: 0.5754 - val_accuracy: 0.7750 - val_loss: 0.5912
# Epoch 14/40
# 595/600 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7928 - loss: 0.5405
# Epoch 14: val_loss did not improve from 0.58524
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.7927 - loss: 0.5406 - val_accuracy: 0.7205 - val_loss: 0.7804
# Epoch 15/40
# 599/600 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7946 - loss: 0.5245
# Epoch 15: val_loss did not improve from 0.58524
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.7946 - loss: 0.5246 - val_accuracy: 0.7275 - val_loss: 0.7516
# Epoch 16/40
# 598/600 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8031 - loss: 0.5125
# Epoch 16: val_loss did not improve from 0.58524
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8030 - loss: 0.5126 - val_accuracy: 0.7722 - val_loss: 0.6139
# Epoch 17/40
# 594/600 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8101 - loss: 0.4993
# Epoch 17: val_loss improved from 0.58524 to 0.50137, saving model to C:\Users\cimss\PycharmProjects\Deepnet\venv\EyeNetDeepNeuralNetwork\model/adam_weights.keras
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8101 - loss: 0.4994 - val_accuracy: 0.8022 - val_loss: 0.5014
# Epoch 18/40
# 598/600 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8144 - loss: 0.4840
# Epoch 18: val_loss did not improve from 0.50137
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8143 - loss: 0.4841 - val_accuracy: 0.8022 - val_loss: 0.5087
# Epoch 19/40
# 598/600 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8139 - loss: 0.4733
# Epoch 19: val_loss did not improve from 0.50137
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8138 - loss: 0.4733 - val_accuracy: 0.7972 - val_loss: 0.5074
# Epoch 20/40
# 597/600 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8241 - loss: 0.4560
# Epoch 20: val_loss did not improve from 0.50137
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8241 - loss: 0.4561 - val_accuracy: 0.7575 - val_loss: 0.7256
# Epoch 21/40
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8263 - loss: 0.4501
# Epoch 21: val_loss did not improve from 0.50137
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8263 - loss: 0.4501 - val_accuracy: 0.7730 - val_loss: 0.6164
# Epoch 22/40
# 599/600 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8238 - loss: 0.4475
# Epoch 22: val_loss did not improve from 0.50137
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8238 - loss: 0.4475 - val_accuracy: 0.7920 - val_loss: 0.5537
# Epoch 23/40
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8323 - loss: 0.4306
# Epoch 23: val_loss improved from 0.50137 to 0.46114, saving model to C:\Users\cimss\PycharmProjects\Deepnet\venv\EyeNetDeepNeuralNetwork\model/adam_weights.keras
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8323 - loss: 0.4306 - val_accuracy: 0.8105 - val_loss: 0.4611
# Epoch 24/40
# 599/600 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8348 - loss: 0.4238
# Epoch 24: val_loss improved from 0.46114 to 0.44576, saving model to C:\Users\cimss\PycharmProjects\Deepnet\venv\EyeNetDeepNeuralNetwork\model/adam_weights.keras
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8348 - loss: 0.4238 - val_accuracy: 0.8145 - val_loss: 0.4458
# Epoch 25/40
# 597/600 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8449 - loss: 0.4035
# Epoch 25: val_loss did not improve from 0.44576
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8449 - loss: 0.4035 - val_accuracy: 0.7775 - val_loss: 0.5589
# Epoch 26/40
# 599/600 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8448 - loss: 0.3983
# Epoch 26: val_loss did not improve from 0.44576
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8448 - loss: 0.3983 - val_accuracy: 0.8210 - val_loss: 0.4601
# Epoch 27/40
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8506 - loss: 0.3824
# Epoch 27: val_loss did not improve from 0.44576
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8506 - loss: 0.3824 - val_accuracy: 0.7179 - val_loss: 0.7399
# Epoch 28/40
# 594/600 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8479 - loss: 0.3907
# Epoch 28: val_loss did not improve from 0.44576
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8480 - loss: 0.3906 - val_accuracy: 0.6922 - val_loss: 1.0548
# Epoch 29/40
# 598/600 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8488 - loss: 0.3869
# Epoch 29: val_loss did not improve from 0.44576
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8488 - loss: 0.3868 - val_accuracy: 0.7637 - val_loss: 0.5821
# Epoch 30/40
# 596/600 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8571 - loss: 0.3673
# Epoch 30: val_loss did not improve from 0.44576
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8571 - loss: 0.3673 - val_accuracy: 0.8214 - val_loss: 0.4461
# Epoch 31/40
# 595/600 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8651 - loss: 0.3492
# Epoch 31: val_loss did not improve from 0.44576
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8651 - loss: 0.3493 - val_accuracy: 0.7764 - val_loss: 0.6955
# Epoch 32/40
# 597/600 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8575 - loss: 0.3608
# Epoch 32: val_loss improved from 0.44576 to 0.43925, saving model to C:\Users\cimss\PycharmProjects\Deepnet\venv\EyeNetDeepNeuralNetwork\model/adam_weights.keras
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8575 - loss: 0.3607 - val_accuracy: 0.8345 - val_loss: 0.4393
# Epoch 33/40
# 595/600 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8682 - loss: 0.3451
# Epoch 33: val_loss improved from 0.43925 to 0.38983, saving model to C:\Users\cimss\PycharmProjects\Deepnet\venv\EyeNetDeepNeuralNetwork\model/adam_weights.keras
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8682 - loss: 0.3452 - val_accuracy: 0.8515 - val_loss: 0.3898
# Epoch 34/40
# 599/600 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8688 - loss: 0.3421
# Epoch 34: val_loss did not improve from 0.38983
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8688 - loss: 0.3421 - val_accuracy: 0.8394 - val_loss: 0.4188
# Epoch 35/40
# 599/600 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8702 - loss: 0.3412
# Epoch 35: val_loss improved from 0.38983 to 0.34013, saving model to C:\Users\cimss\PycharmProjects\Deepnet\venv\EyeNetDeepNeuralNetwork\model/adam_weights.keras
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8702 - loss: 0.3412 - val_accuracy: 0.8679 - val_loss: 0.3401
# Epoch 36/40
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8746 - loss: 0.3286
# Epoch 36: val_loss did not improve from 0.34013
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8746 - loss: 0.3286 - val_accuracy: 0.8262 - val_loss: 0.4701
# Epoch 37/40
# 594/600 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8699 - loss: 0.3343
# Epoch 37: val_loss did not improve from 0.34013
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8700 - loss: 0.3342 - val_accuracy: 0.8399 - val_loss: 0.3966
# Epoch 38/40
# 594/600 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8787 - loss: 0.3118
# Epoch 38: val_loss did not improve from 0.34013
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8786 - loss: 0.3120 - val_accuracy: 0.8537 - val_loss: 0.3903
# Epoch 39/40
# 597/600 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8714 - loss: 0.3223
# Epoch 39: val_loss improved from 0.34013 to 0.33909, saving model to C:\Users\cimss\PycharmProjects\Deepnet\venv\EyeNetDeepNeuralNetwork\model/adam_weights.keras
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8714 - loss: 0.3222 - val_accuracy: 0.8672 - val_loss: 0.3391
# Epoch 40/40
# 597/600 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8746 - loss: 0.3164
# Epoch 40: val_loss did not improve from 0.33909
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8746 - loss: 0.3164 - val_accuracy: 0.7409 - val_loss: 0.7152
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# EyeNet Adam Validation Accuracy  :  74.4375
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# EyeNet Adam Testing Accuracy  :  74.08765205799034
# EyeNet Adam Testing Precision : 78.01630780899264
# EyeNet Adam Testing Recall    : 75.0808102397848
# EyeNet Adam Testing FScore    : 74.12645857856997

# %%
#train extension model with padding as 'same and valid'
extension_model = Sequential()
extension_model.add(InputLayer(input_shape=(X_train.shape[1],X_train.shape[2],X_train.shape[3])))
extension_model.add(Conv2D(25, (5, 5), activation='relu', strides=(1, 1), padding='same'))
extension_model.add(MaxPool2D(pool_size=(2, 2), padding='same'))
extension_model.add(Conv2D(50, (5, 5), activation='relu', strides=(2, 2), padding='same'))
extension_model.add(MaxPool2D(pool_size=(2, 2), padding='same'))
extension_model.add(BatchNormalization())
extension_model.add(Conv2D(70, (3, 3), activation='relu', strides=(2, 2), padding='same'))
extension_model.add(MaxPool2D(pool_size=(2, 2), padding='valid'))
extension_model.add(BatchNormalization())
extension_model.add(Flatten())
extension_model.add(Dense(units=100, activation='relu'))
extension_model.add(Dense(units=100, activation='relu'))
extension_model.add(Dropout(0.25))
extension_model.add(Dense(units=y_train.shape[1], activation='softmax'))
extension_model.compile(loss='categorical_crossentropy', optimizer="adam", metrics=['accuracy'])
if os.path.exists(r"C:\Users\Adil shaik\PycharmProjects\PythonProject\.venv\EyeNetDeepNeuralNetwork\model/extension_weights.keras") == False:
    model_check_point = ModelCheckpoint(filepath=r'C:\Users\Adil shaik\PycharmProjects\PythonProject\.venv\EyeNetDeepNeuralNetwork\model/extension_weights.keras', verbose = 1, save_best_only = True)
    hist = extension_model.fit(X_train, y_train, epochs = 40, validation_data=(X_test, y_test), callbacks=[model_check_point], verbose=1)
    f = open(r'C:\Users\Adil shaik\PycharmProjects\PythonProject\.venv\EyeNetDeepNeuralNetwork\model/extension_history.pckl', 'wb')
    pickle.dump(hist.history, f)
    f.close()    
else:
    extension_model.load_weights(r"C:\Users\Adil shaik\PycharmProjects\PythonProject\.venv\EyeNetDeepNeuralNetwork\model/extension_weights.keras")
#perfrom prediction on test data
predict = extension_model.predict(X_val)
predict = np.argmax(predict, axis=1)
y_val1 = np.argmax(y_val, axis=1)
acc = accuracy_score(y_val1, predict) * 100
print("Extension with Adam & Valid Padding Validation Accuracy  :  "+str(acc))
predict = extension_model.predict(X_test)
predict = np.argmax(predict, axis=1)
y_test1 = np.argmax(y_test, axis=1)
calculateMetrics("Extension with Adam & Valid Padding Testing", predict, y_test1)
# Out:
# Epoch 1/40
# 599/600 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5501 - loss: 1.0917
# Epoch 1: val_loss improved from inf to 1.19236, saving model to C:\Users\cimss\PycharmProjects\Deepnet\venv\EyeNetDeepNeuralNetwork\model/extension_weights.keras
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.5502 - loss: 1.0913 - val_accuracy: 0.5359 - val_loss: 1.1924
# Epoch 2/40
# 599/600 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6658 - loss: 0.8301
# Epoch 2: val_loss improved from 1.19236 to 0.76236, saving model to C:\Users\cimss\PycharmProjects\Deepnet\venv\EyeNetDeepNeuralNetwork\model/extension_weights.keras
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.6659 - loss: 0.8300 - val_accuracy: 0.6781 - val_loss: 0.7624
# Epoch 3/40
# 599/600 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7118 - loss: 0.7146
# Epoch 3: val_loss improved from 0.76236 to 0.65270, saving model to C:\Users\cimss\PycharmProjects\Deepnet\venv\EyeNetDeepNeuralNetwork\model/extension_weights.keras
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.7118 - loss: 0.7145 - val_accuracy: 0.7350 - val_loss: 0.6527
# Epoch 4/40
# 597/600 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7575 - loss: 0.6039
# Epoch 4: val_loss did not improve from 0.65270
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.7576 - loss: 0.6038 - val_accuracy: 0.7304 - val_loss: 0.6591
# Epoch 5/40
# 597/600 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7912 - loss: 0.5177
# Epoch 5: val_loss improved from 0.65270 to 0.52393, saving model to C:\Users\cimss\PycharmProjects\Deepnet\venv\EyeNetDeepNeuralNetwork\model/extension_weights.keras
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.7913 - loss: 0.5176 - val_accuracy: 0.7840 - val_loss: 0.5239
# Epoch 6/40
# 595/600 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8133 - loss: 0.4485
# Epoch 6: val_loss improved from 0.52393 to 0.50393, saving model to C:\Users\cimss\PycharmProjects\Deepnet\venv\EyeNetDeepNeuralNetwork\model/extension_weights.keras
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.8133 - loss: 0.4484 - val_accuracy: 0.7944 - val_loss: 0.5039
# Epoch 7/40
# 599/600 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8371 - loss: 0.3968
# Epoch 7: val_loss improved from 0.50393 to 0.35857, saving model to C:\Users\cimss\PycharmProjects\Deepnet\venv\EyeNetDeepNeuralNetwork\model/extension_weights.keras
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.8371 - loss: 0.3968 - val_accuracy: 0.8449 - val_loss: 0.3586
# Epoch 8/40
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8580 - loss: 0.3458
# Epoch 8: val_loss improved from 0.35857 to 0.30236, saving model to C:\Users\cimss\PycharmProjects\Deepnet\venv\EyeNetDeepNeuralNetwork\model/extension_weights.keras
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.8580 - loss: 0.3458 - val_accuracy: 0.8794 - val_loss: 0.3024
# Epoch 9/40
# 596/600 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8697 - loss: 0.3150
# Epoch 9: val_loss did not improve from 0.30236
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.8697 - loss: 0.3150 - val_accuracy: 0.8435 - val_loss: 0.3873
# Epoch 10/40
# 595/600 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8845 - loss: 0.2819
# Epoch 10: val_loss improved from 0.30236 to 0.30070, saving model to C:\Users\cimss\PycharmProjects\Deepnet\venv\EyeNetDeepNeuralNetwork\model/extension_weights.keras
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.8845 - loss: 0.2820 - val_accuracy: 0.8752 - val_loss: 0.3007
# Epoch 11/40
# 595/600 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8987 - loss: 0.2492
# Epoch 11: val_loss improved from 0.30070 to 0.24489, saving model to C:\Users\cimss\PycharmProjects\Deepnet\venv\EyeNetDeepNeuralNetwork\model/extension_weights.keras
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.8987 - loss: 0.2493 - val_accuracy: 0.8909 - val_loss: 0.2449
# Epoch 12/40
# 596/600 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9040 - loss: 0.2331
# Epoch 12: val_loss improved from 0.24489 to 0.22056, saving model to C:\Users\cimss\PycharmProjects\Deepnet\venv\EyeNetDeepNeuralNetwork\model/extension_weights.keras
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.9039 - loss: 0.2332 - val_accuracy: 0.9082 - val_loss: 0.2206
# Epoch 13/40
# 596/600 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9084 - loss: 0.2146
# Epoch 13: val_loss improved from 0.22056 to 0.19587, saving model to C:\Users\cimss\PycharmProjects\Deepnet\venv\EyeNetDeepNeuralNetwork\model/extension_weights.keras
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.9084 - loss: 0.2146 - val_accuracy: 0.9148 - val_loss: 0.1959
# Epoch 14/40
# 599/600 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9144 - loss: 0.2052
# Epoch 14: val_loss did not improve from 0.19587
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.9144 - loss: 0.2052 - val_accuracy: 0.8100 - val_loss: 0.5966
# Epoch 15/40
# 599/600 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9144 - loss: 0.1987
# Epoch 15: val_loss did not improve from 0.19587
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.9144 - loss: 0.1987 - val_accuracy: 0.9143 - val_loss: 0.2089
# Epoch 16/40
# 599/600 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9190 - loss: 0.1880
# Epoch 16: val_loss did not improve from 0.19587
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.9190 - loss: 0.1881 - val_accuracy: 0.9087 - val_loss: 0.2038
# Epoch 17/40
# 599/600 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9218 - loss: 0.1822
# Epoch 17: val_loss did not improve from 0.19587
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.9218 - loss: 0.1822 - val_accuracy: 0.8742 - val_loss: 0.2881
# Epoch 18/40
# 598/600 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9183 - loss: 0.1879
# Epoch 18: val_loss did not improve from 0.19587
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.9183 - loss: 0.1878 - val_accuracy: 0.9060 - val_loss: 0.2074
# Epoch 19/40
# 597/600 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9260 - loss: 0.1709
# Epoch 19: val_loss improved from 0.19587 to 0.15537, saving model to C:\Users\cimss\PycharmProjects\Deepnet\venv\EyeNetDeepNeuralNetwork\model/extension_weights.keras
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.9260 - loss: 0.1709 - val_accuracy: 0.9327 - val_loss: 0.1554
# Epoch 20/40
# 599/600 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9270 - loss: 0.1680
# Epoch 20: val_loss improved from 0.15537 to 0.14595, saving model to C:\Users\cimss\PycharmProjects\Deepnet\venv\EyeNetDeepNeuralNetwork\model/extension_weights.keras
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.9270 - loss: 0.1680 - val_accuracy: 0.9328 - val_loss: 0.1460
# Epoch 21/40
# 596/600 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9312 - loss: 0.1604
# Epoch 21: val_loss improved from 0.14595 to 0.14538, saving model to C:\Users\cimss\PycharmProjects\Deepnet\venv\EyeNetDeepNeuralNetwork\model/extension_weights.keras
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.9312 - loss: 0.1604 - val_accuracy: 0.9343 - val_loss: 0.1454
# Epoch 22/40
# 597/600 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9326 - loss: 0.1518
# Epoch 22: val_loss did not improve from 0.14538
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.9326 - loss: 0.1518 - val_accuracy: 0.9233 - val_loss: 0.1773
# Epoch 23/40
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9334 - loss: 0.1519
# Epoch 23: val_loss did not improve from 0.14538
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.9334 - loss: 0.1519 - val_accuracy: 0.9310 - val_loss: 0.1581
# Epoch 24/40
# 596/600 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9344 - loss: 0.1461
# Epoch 24: val_loss did not improve from 0.14538
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.9344 - loss: 0.1461 - val_accuracy: 0.9295 - val_loss: 0.1548
# Epoch 25/40
# 598/600 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9350 - loss: 0.1445
# Epoch 25: val_loss did not improve from 0.14538
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.9350 - loss: 0.1445 - val_accuracy: 0.9243 - val_loss: 0.1622
# Epoch 26/40
# 597/600 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9358 - loss: 0.1370
# Epoch 26: val_loss did not improve from 0.14538
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.9358 - loss: 0.1371 - val_accuracy: 0.9253 - val_loss: 0.1688
# Epoch 27/40
# 595/600 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9371 - loss: 0.1363
# Epoch 27: val_loss did not improve from 0.14538
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.9370 - loss: 0.1363 - val_accuracy: 0.9255 - val_loss: 0.1648
# Epoch 28/40
# 598/600 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9392 - loss: 0.1337
# Epoch 28: val_loss did not improve from 0.14538
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.9392 - loss: 0.1337 - val_accuracy: 0.9230 - val_loss: 0.1809
# Epoch 29/40
# 595/600 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9388 - loss: 0.1283
# Epoch 29: val_loss did not improve from 0.14538
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.9388 - loss: 0.1284 - val_accuracy: 0.9230 - val_loss: 0.1638
# Epoch 30/40
# 596/600 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9404 - loss: 0.1285
# Epoch 30: val_loss did not improve from 0.14538
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.9403 - loss: 0.1285 - val_accuracy: 0.9175 - val_loss: 0.1913
# Epoch 31/40
# 596/600 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9408 - loss: 0.1275
# Epoch 31: val_loss improved from 0.14538 to 0.13633, saving model to C:\Users\cimss\PycharmProjects\Deepnet\venv\EyeNetDeepNeuralNetwork\model/extension_weights.keras
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.9408 - loss: 0.1276 - val_accuracy: 0.9320 - val_loss: 0.1363
# Epoch 32/40
# 596/600 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9403 - loss: 0.1285
# Epoch 32: val_loss improved from 0.13633 to 0.13245, saving model to C:\Users\cimss\PycharmProjects\Deepnet\venv\EyeNetDeepNeuralNetwork\model/extension_weights.keras
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.9403 - loss: 0.1285 - val_accuracy: 0.9320 - val_loss: 0.1325
# Epoch 33/40
# 596/600 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9438 - loss: 0.1218
# Epoch 33: val_loss did not improve from 0.13245
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.9438 - loss: 0.1218 - val_accuracy: 0.9335 - val_loss: 0.1373
# Epoch 34/40
# 597/600 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9466 - loss: 0.1143
# Epoch 34: val_loss did not improve from 0.13245
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.9466 - loss: 0.1143 - val_accuracy: 0.9347 - val_loss: 0.1379
# Epoch 35/40
# 599/600 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9401 - loss: 0.1235
# Epoch 35: val_loss did not improve from 0.13245
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.9401 - loss: 0.1235 - val_accuracy: 0.8707 - val_loss: 0.3950
# Epoch 36/40
# 599/600 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9432 - loss: 0.1126
# Epoch 36: val_loss did not improve from 0.13245
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.9432 - loss: 0.1126 - val_accuracy: 0.9358 - val_loss: 0.1363
# Epoch 37/40
# 596/600 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9414 - loss: 0.1244
# Epoch 37: val_loss did not improve from 0.13245
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.9414 - loss: 0.1244 - val_accuracy: 0.9315 - val_loss: 0.1391
# Epoch 38/40
# 594/600 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9420 - loss: 0.1188
# Epoch 38: val_loss did not improve from 0.13245
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.9420 - loss: 0.1189 - val_accuracy: 0.9248 - val_loss: 0.1595
# Epoch 39/40
# 594/600 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9418 - loss: 0.1157
# Epoch 39: val_loss did not improve from 0.13245
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - accuracy: 0.9418 - loss: 0.1157 - val_accuracy: 0.9303 - val_loss: 0.1611
# Epoch 40/40
# 598/600 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9416 - loss: 0.1232
# Epoch 40: val_loss improved from 0.13245 to 0.11752, saving model to C:\Users\cimss\PycharmProjects\Deepnet\venv\EyeNetDeepNeuralNetwork\model/extension_weights.keras
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.9416 - loss: 0.1232 - val_accuracy: 0.9385 - val_loss: 0.1175
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Extension with Adam & Valid Padding Validation Accuracy  :  94.375
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# Extension with Adam & Valid Padding Testing Accuracy  :  93.85102482919513
# Extension with Adam & Valid Padding Testing Precision : 93.35940994033018
# Extension with Adam & Valid Padding Testing Recall    : 93.48529174430834
# Extension with Adam & Valid Padding Testing FScore    : 93.39439323610273

# %%
#comparison graph
df = pd.DataFrame([['EyeNet with SGD','Accuracy',accuracy[0]],['EyeNet with SGD','Precision',precision[0]],['EyeNet with SGD','Recall',recall[0]],['EyeNet with SGD','FSCORE',fscore[0]],
                   
                   ['Extension with Adam & Valid','Accuracy',accuracy[2]],['Extension with Adam & Valid','Precision',precision[2]],['Extension with Adam & Valid','Recall',recall[2]],['Extension with Adam & Valid','FSCORE',fscore[2]],
                  ],columns=['Parameters','Algorithms','Value'])
df.pivot(index = "Parameters", columns = "Algorithms", values = "Value").plot(kind='bar', figsize=(8, 2))
plt.title("All Algorithms Performance Graph")
plt.show()

# %%
(len(accuracy))
# Out:
# 3

# %%
#display all algorithm performnace
algorithms = ['EyeNet with SGD','EyeNet With Adam','Extension with Adam & Valid']
data = []
for i in range(len(accuracy)):
    data.append([algorithms[i], accuracy[i], precision[i], recall[i], fscore[i]])
data = pd.DataFrame(data, columns=['Algorithm Name', 'Accuracy', 'Precision', 'Recall', 'FSCORE'])
data
# Out:
#                 Algorithm Name   Accuracy  Precision     Recall     FSCORE
# 0              EyeNet with SGD  78.653558  78.222622  76.662981  76.258605
# 1             EyeNet With Adam  74.087652  78.016308  75.080810  74.126459
# 2  Extension with Adam & Valid  93.851025  93.359410  93.485292  93.394393

# %%
def values(filename, acc, loss):
    f = open(filename, 'rb')
    train_values = pickle.load(f)
    f.close()
    accuracy_value = train_values[acc][0:20]
    loss_value = train_values[loss][0:20]
    return accuracy_value, loss_value

# %%
sgd_acc, sgd_loss = values(r"C:\Users\Adil shaik\PycharmProjects\PythonProject\.venv\EyeNetDeepNeuralNetwork\model/sgd_history.pckl", "accuracy", "loss")
adam_acc, adam_loss = values(r"C:\Users\Adil shaik\PycharmProjects\PythonProject\.venv\EyeNetDeepNeuralNetwork\model/adam_history.pckl", "accuracy", "loss")
extension_acc, extension_loss = values(r"C:\Users\Adil shaik\PycharmProjects\PythonProject\.venv\EyeNetDeepNeuralNetwork\model/extension_history.pckl", "accuracy", "loss")
    
plt.figure(figsize=(6,4))
plt.grid(True)
plt.xlabel('EPOCH')
plt.ylabel('Accuracy')
plt.plot(sgd_acc, 'ro-', color = 'green')
plt.plot(adam_acc, 'ro-', color = 'blue')
plt.plot(extension_acc, 'ro-', color = 'black')
plt.legend(['EyeDeepNet SGD', 'EyeDeepNet Adam', 'Extension with Valid & Same padding'], loc='lower right')
plt.title('All Algorithm Training Accuracy Graph')
plt.show()

# %%
#use this function to predict fish species uisng extension model
def predict(image_path):
    image = cv2.imread(image_path)#read test image
    img = cv2.resize(image, (32,32))#resize image
    im2arr = np.array(img)
    im2arr = im2arr.reshape(1,32,32,3)#convert image as 4 dimension
    img = np.asarray(im2arr)
    img = img.astype('float32')#convert image features as float
    img = img/255 #normalized image
    predict = extension_model.predict(img)#perform prediction on test image
    predict = np.argmax(predict)
    img = cv2.imread(image_path)
    img = cv2.resize(img, (400,300))#display image with predicted output
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    cv2.putText(img, 'Predicted As : '+labels[predict], (10, 25),  cv2.FONT_HERSHEY_SIMPLEX,0.7, (0, 0, 255), 2)
    plt.figure(figsize=(4,3))
    plt.imshow(img)

# %%
#call this function to predict retinal diseases
predict(r"C:\Users\cimss\PycharmProjects\Deepnet\venv\EyeNetDeepNeuralNetwork\testImages/0.png")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step

# %%
#call this function to predict retinal diseases
predict(r"C:\Users\cimss\PycharmProjects\Deepnet\venv\EyeNetDeepNeuralNetwork\testImages/3.png")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step

# %%
#call this function to predict retinal diseases
predict(r"C:\Users\Adil shaik\PycharmProjects\PythonProject\.venv\EyeNetDeepNeuralNetwork\testImages/4.png")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step

# %%
#call this function to predict retinal diseases
predict(r"C:\Users\Adil shaik\PycharmProjects\PythonProject\.venv\EyeNetDeepNeuralNetwork\testImages/7.png")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
